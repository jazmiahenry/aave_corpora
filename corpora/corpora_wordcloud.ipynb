# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from PIL import Image

# %%
with open('corpora.txt') as f:
    lines = f.readlines()

# %%
lines
# Out:
# [' thanksgivingclapback\n',
#  'thanksgivingclapback vine by  \n',
#  'i missed this thanksgivingclapback \n',
#  'thanksgivingclapback \n',
#  'when yo grandma tripping about not hearing from you since your birthday thanksgivingclapback \n',
#  'no se olviden de revisar el thanksgivingclapback para reir un rato\n',
#  'thanksgivingclapback vine by  \n',
#  'the thanksgivingclapback is the most savage hashtag on twitter  i love it \n',
#  'thanksgivingclapback  \n',
#  'im still laughing at these thanksgivingclapback \n',
#  'gran you should retire that obsession with nicki minaj\n',
#  'me you should retire that wig\n',
#  'thanksgivingclapback late \n',
#  'thanksgivingclapback goteeemmm \n',
#  'thanksgiving with black families meme thanksgivingclapback vine by _ \n',
#  'got cod ghost just to destroy it worstgame thanksgivingclapback\n',
#  'thanksgivingclapback \n',
#  'thanksgivingclapback  \n',
# ...

# %%
unique_string=(" ").join(lines)

# %%
def plot_cloud(wordcloud):
    # Set figure size
    plt.figure(figsize=(40, 30))
    # Display image
    plt.imshow(wordcloud) 
    # No axis details
    plt.axis("off")

# %%
# Generate word cloud
mask = np.array(Image.open("/Users/jazmiahenry/aave/src/corpora/africa.jpeg"))
wordcloud = WordCloud(width= 3000, height = 2000, random_state=1, mask= mask, background_color='green', colormap='RdGy_r', collocations=False, stopwords = STOPWORDS).generate(unique_string)
# Plot
plot_cloud(wordcloud)

# %%
result = len(unique_string.split())

print("There are " + str(result) + " words.")
# Out:
# There are 141341 words.

# %%
str_list = unique_string.split()
unique_words = set(str_list)
      
for words in unique_words :
    print('Frequency of ', words , 'is :', str_list.count(words))
# Out:
# Frequency of  pretend is : 4
# Frequency of  fncg is : 1
# Frequency of  citizenry is : 1
# Frequency of  mt is : 1
# Frequency of  blackdads is : 1
# Frequency of  grouppalestine is : 3
# Frequency of  launch is : 1
# Frequency of  mississippi is : 5
# Frequency of  misogyny is : 1
# Frequency of  sheesh is : 2
# Frequency of  horssujet is : 1
# Frequency of  fuckforgiveness is : 1
# Frequency of  soit is : 2
# Frequency of  progress is : 8
# Frequency of  burbs is : 1
# Frequency of  pieces is : 2
# Frequency of  middle is : 9
# Frequency of  smidge is : 1
# Frequency of  unless is : 12
# Frequency of  porra is : 1
# Frequency of  gma is : 8
# Frequency of  lmfaoooooo is : 1
# Frequency of  arranque is : 1
# Frequency of  cherry is : 1
# Frequency of  treasonoustraitortrump is : 5
# Frequency of  amis is : 1
# Frequency of  workplaces is : 4
# Frequency of  bunny is : 1
# Frequency of  addressed is : 2
# Frequency of  letters is : 1
# Frequency of  cu is : 1
# ...

# %%
frequency
# Out:
# 1

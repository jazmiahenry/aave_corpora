# %%
#pip install lyricsgenius: https://lyricsgenius.readthedocs.io/en/master/
from lyricsgenius import Genius
from genius_config import *

# %%
genius = Genius(client_access_token)

# %%
artist = genius.search_artist('Kanye West', max_songs = 200)
#genius api has a tendency to break due to a time out error unexpectedly. If this happens, reference the next chunk of code to overcome 
#this problem without having to rerun your cell repeatedly
# Out:
# Searching for songs by Kanye West...
#
# Song 1: "Mercy"
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#
# ...

# %%
# instantiate this chunk of code if genius api fails repeatedly. 
artists = []
while True:
    try:
        artist = artists.append(genius.search_artist('Kanye West', max_songs=150))
        break
    except:
        pass
# Out:
# Searching for songs by Kanye West...
#
# Song 1: "Mercy"
# Song 2: "Father Stretch My Hands, Pt. 1"
# Song 3: "Monster"
# Song 4: "Ultralight Beam"
# Song 5: "Bound 2"
# Searching for songs by Kanye West...
#
# Song 1: "Mercy"
# Song 2: "Father Stretch My Hands, Pt. 1"
# Song 3: "Monster"
# Song 4: "Ultralight Beam"
# Song 5: "Bound 2"
# Song 6: "New Slaves"
# Song 7: "Blood on the Leaves"
# Searching for songs by Kanye West...
#
# Song 1: "Mercy"
# Song 2: "Father Stretch My Hands, Pt. 1"
# Song 3: "Monster"
# Song 4: "Ultralight Beam"
# Song 5: "Bound 2"
# Song 6: "New Slaves"
# Searching for songs by Kanye West...
#
# Song 1: "Mercy"
# Song 2: "Father Stretch My Hands, Pt. 1"
# Song 3: "Monster"
# Song 4: "Ultralight Beam"
# Song 5: "Bound 2"
# Song 6: "New Slaves"
# Song 7: "Blood on the Leaves"
# Song 8: "Black Skinhead"
# Song 9: "Runaway"
# Song 10: "All Mine"
# Song 11: "No More Parties In LA"
# Song 12: "Famous"
# Song 13: "POWER"
# Song 14: "Real Friends"
# ...

# %%
artist.save_lyrics()
# Out:
# Wrote Lyrics_JAYZ.json.
